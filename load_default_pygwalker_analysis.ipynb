# %%
import pandas as pd
import pygwalker as pyg

# %%
df = pd.read_csv ('~/Downloads/sample_2023/sample_svcg_2023.csv')

# %%
walker = pyg.walk(df)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-00063fc29b6fa67dOcmwt1d4RX8nfDsj" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "00063fc29b6fa67dOcmwt1d4RX8nfDsj") {
#             var iframe = document.getElementById("gwalker-00063fc29b6fa67dOcmwt1d4RX8nfDsj");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>
