# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Concatenate, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
# Import the dataset generator
from sample_dataset import generate_credit_risk_dataset, prepare_data_for_models

# %%
def create_monolithic_model(input_dim=20):
    """
    Create a monolithic neural network model
    """
    model = Sequential([
        Dense(128, activation='relu', input_shape=(input_dim,)),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(32, activation='relu'),
        Dropout(0.2),
        Dense(1, activation='sigmoid')
    ])
    
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='binary_crossentropy',
        metrics=['accuracy', 'precision', 'recall']
    )
    
    return model

# %%
def create_meta_learning_model():
    """
    Create a meta-learning model with specialized base models
    """
    # Base model 1: Financial features (first 10 features)
    financial_input = Input(shape=(10,), name='financial_input')
    x1 = Dense(64, activation='relu')(financial_input)
    x1 = Dropout(0.3)(x1)
    x1 = Dense(32, activation='relu')(x1)
    x1 = Dropout(0.2)(x1)
    financial_output = Dense(16, activation='relu', name='financial_features')(x1)
    
    # Base model 2: Behavioral features (last 10 features)
    behavioral_input = Input(shape=(10,), name='behavioral_input')
    x2 = Dense(64, activation='relu')(behavioral_input)
    x2 = Dropout(0.3)(x2)
    x2 = Dense(32, activation='relu')(x2)
    x2 = Dropout(0.2)(x2)
    behavioral_output = Dense(16, activation='relu', name='behavioral_features')(x2)
    
    # Meta-model: Combines outputs from both base models
    combined = Concatenate(name='feature_fusion')([financial_output, behavioral_output])
    z = Dense(32, activation='relu')(combined)
    z = Dropout(0.3)(z)
    z = Dense(16, activation='relu')(z)
    z = Dropout(0.2)(z)
    final_output = Dense(1, activation='sigmoid', name='risk_prediction')(z)
    
    meta_model = Model(
        inputs=[financial_input, behavioral_input],
        outputs=final_output,
        name='meta_learning_model'
    )
    
    meta_model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='binary_crossentropy',
        metrics=['accuracy', 'precision', 'recall']
    )
    
    return meta_model

# %%
def train_and_evaluate_models():
    """
    Train and evaluate both models on the credit risk dataset
    """
    print("=" * 60)
    print("MONOLITHIC vs META-LEARNING MODEL COMPARISON")
    print("=" * 60)
    
    # Generate dataset
    print("\n1. Generating credit risk dataset...")
    X, y, feature_names, df = generate_credit_risk_dataset(n_samples=8000)
    data = prepare_data_for_models(X, y, test_size=0.2)
    
    print(f"   Dataset size: {X.shape[0]} samples, {X.shape[1]} features")
    print(f"   Default rate: {np.mean(y):.1%}")
    print(f"   Train/Test split: {len(data['monolithic']['y_train'])}/{len(data['monolithic']['y_test'])}")
    
    # Early stopping callback
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True,
        verbose=0
    )
    
    print("\n2. Training Monolithic Model...")
    print("-" * 40)
    
    # Train monolithic model
    monolithic_model = create_monolithic_model()
    mono_history = monolithic_model.fit(
        data['monolithic']['X_train'],
        data['monolithic']['y_train'],
        epochs=100,
        batch_size=64,
        validation_split=0.2,
        callbacks=[early_stopping],
        verbose=1
    )
    
    # Evaluate monolithic model
    mono_train_results = monolithic_model.evaluate(
        data['monolithic']['X_train'], 
        data['monolithic']['y_train'], 
        verbose=0
    )
    mono_test_results = monolithic_model.evaluate(
        data['monolithic']['X_test'], 
        data['monolithic']['y_test'], 
        verbose=0
    )
    
    print("\n3. Training Meta-Learning Model...")
    print("-" * 40)
    
    # Train meta-learning model
    meta_model = create_meta_learning_model()
    meta_history = meta_model.fit(
        data['meta_learning']['X_train'],
        data['meta_learning']['y_train'],
        epochs=100,
        batch_size=64,
        validation_split=0.2,
        callbacks=[early_stopping],
        verbose=1
    )
    
    # Evaluate meta-learning model
    meta_train_results = meta_model.evaluate(
        data['meta_learning']['X_train'], 
        data['meta_learning']['y_train'], 
        verbose=0
    )
    meta_test_results = meta_model.evaluate(
        data['meta_learning']['X_test'], 
        data['meta_learning']['y_test'], 
        verbose=0
    )
    
    print("\n4. RESULTS COMPARISON")
    print("=" * 60)
    
    # Print results
    metrics = ['Loss', 'Accuracy', 'Precision', 'Recall']
    
    print(f"{'Model':<20} {'Dataset':<10} {'Loss':<8} {'Accuracy':<10} {'Precision':<10} {'Recall':<8}")
    print("-" * 70)
    print(f"{'Monolithic':<20} {'Train':<10} {mono_train_results[0]:<8.4f} {mono_train_results[1]:<10.4f} {mono_train_results[2]:<10.4f} {mono_train_results[3]:<8.4f}")
    print(f"{'Monolithic':<20} {'Test':<10} {mono_test_results[0]:<8.4f} {mono_test_results[1]:<10.4f} {mono_test_results[2]:<10.4f} {mono_test_results[3]:<8.4f}")
    print(f"{'Meta-Learning':<20} {'Train':<10} {meta_train_results[0]:<8.4f} {meta_train_results[1]:<10.4f} {meta_train_results[2]:<10.4f} {meta_train_results[3]:<8.4f}")
    print(f"{'Meta-Learning':<20} {'Test':<10} {meta_test_results[0]:<8.4f} {meta_test_results[1]:<10.4f} {meta_test_results[2]:<10.4f} {meta_test_results[3]:<8.4f}")
    
    # Calculate improvement
    accuracy_improvement = (meta_test_results[1] - mono_test_results[1]) * 100
    precision_improvement = (meta_test_results[2] - mono_test_results[2]) * 100
    
    print(f"\n5. META-LEARNING IMPROVEMENTS:")
    print(f"   Test Accuracy: {accuracy_improvement:+.2f} percentage points")
    print(f"   Test Precision: {precision_improvement:+.2f} percentage points")
    
    # Generate predictions for detailed analysis
    mono_pred = monolithic_model.predict(data['monolithic']['X_test'], verbose=0)
    meta_pred = meta_model.predict(data['meta_learning']['X_test'], verbose=0)
    
    mono_pred_binary = (mono_pred > 0.5).astype(int)
    meta_pred_binary = (meta_pred > 0.5).astype(int)
    
    print(f"\n6. DETAILED CLASSIFICATION REPORTS:")
    print("\nMonolithic Model:")
    print(classification_report(data['monolithic']['y_test'], mono_pred_binary))
    
    print("\nMeta-Learning Model:")
    print(classification_report(data['meta_learning']['y_test'], meta_pred_binary))
    
    # Plot training histories
    plt.figure(figsize=(15, 5))
    
    plt.subplot(1, 3, 1)
    plt.plot(mono_history.history['accuracy'], label='Monolithic Train')
    plt.plot(mono_history.history['val_accuracy'], label='Monolithic Val')
    plt.plot(meta_history.history['accuracy'], label='Meta-Learning Train')
    plt.plot(meta_history.history['val_accuracy'], label='Meta-Learning Val')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 3, 2)
    plt.plot(mono_history.history['loss'], label='Monolithic Train')
    plt.plot(mono_history.history['val_loss'], label='Monolithic Val')
    plt.plot(meta_history.history['loss'], label='Meta-Learning Train')
    plt.plot(meta_history.history['val_loss'], label='Meta-Learning Val')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    
    plt.subplot(1, 3, 3)
    plt.hist(mono_pred, alpha=0.7, label='Monolithic', bins=20)
    plt.hist(meta_pred, alpha=0.7, label='Meta-Learning', bins=20)
    plt.title('Prediction Distribution')
    plt.xlabel('Predicted Probability')
    plt.ylabel('Frequency')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()
    
    return {
        'monolithic_model': monolithic_model,
        'meta_model': meta_model,
        'data': data,
        'results': {
            'monolithic': {'train': mono_train_results, 'test': mono_test_results},
            'meta_learning': {'train': meta_train_results, 'test': meta_test_results}
        }
    }

# %%
if __name__ == "__main__":
    results = train_and_evaluate_models()
# Out:
# ============================================================
# MONOLITHIC vs META-LEARNING MODEL COMPARISON
# ============================================================
#
# 1. Generating credit risk dataset...
#    Dataset size: 8000 samples, 20 features
#    Default rate: 48.6%
#    Train/Test split: 6400/1600
#
# 2. Training Monolithic Model...
# ----------------------------------------
# Epoch 1/100
# /Users/peekay/projects/AI/meta_learning/.venv/lib/python3.11/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6891 - loss: 0.5796 - precision: 0.6684 - recall: 0.7188 - val_accuracy: 0.7797 - val_loss: 0.4728 - val_precision: 0.8011 - val_recall: 0.7233
# Epoch 2/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 0.7488 - loss: 0.5072 - precision: 0.7484 - recall: 0.7304 - val_accuracy: 0.7734 - val_loss: 0.4668 - val_precision: 0.7563 - val_recall: 0.7832
# Epoch 3/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 847us/step - accuracy: 0.7660 - loss: 0.4806 - precision: 0.7649 - recall: 0.7508 - val_accuracy: 0.7805 - val_loss: 0.4646 - val_precision: 0.7749 - val_recall: 0.7686
# Epoch 4/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - accuracy: 0.7666 - loss: 0.4803 - precision: 0.7628 - recall: 0.7564 - val_accuracy: 0.7789 - val_loss: 0.4653 - val_precision: 0.7806 - val_recall: 0.7540
# Epoch 5/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - accuracy: 0.7721 - loss: 0.4773 - precision: 0.7713 - recall: 0.7568 - val_accuracy: 0.7758 - val_loss: 0.4637 - val_precision: 0.7839 - val_recall: 0.7395
# Epoch 6/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - accuracy: 0.7719 - loss: 0.4723 - precision: 0.7755 - recall: 0.7488 - val_accuracy: 0.7688 - val_loss: 0.4655 - val_precision: 0.7588 - val_recall: 0.7638
# Epoch 7/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 766us/step - accuracy: 0.7748 - loss: 0.4629 - precision: 0.7740 - recall: 0.7600 - val_accuracy: 0.7789 - val_loss: 0.4657 - val_precision: 0.7778 - val_recall: 0.7589
# Epoch 8/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 0.7811 - loss: 0.4640 - precision: 0.7800 - recall: 0.7672 - val_accuracy: 0.7773 - val_loss: 0.4652 - val_precision: 0.7876 - val_recall: 0.7379
# Epoch 9/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - accuracy: 0.7824 - loss: 0.4592 - precision: 0.7894 - recall: 0.7552 - val_accuracy: 0.7773 - val_loss: 0.4646 - val_precision: 0.7725 - val_recall: 0.7638
# Epoch 10/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - accuracy: 0.7803 - loss: 0.4559 - precision: 0.7850 - recall: 0.7564 - val_accuracy: 0.7766 - val_loss: 0.4673 - val_precision: 0.7618 - val_recall: 0.7816
# Epoch 11/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7852 - loss: 0.4545 - precision: 0.7851 - recall: 0.7700 - val_accuracy: 0.7789 - val_loss: 0.4636 - val_precision: 0.7863 - val_recall: 0.7443
# Epoch 12/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - accuracy: 0.7777 - loss: 0.4565 - precision: 0.7815 - recall: 0.7552 - val_accuracy: 0.7828 - val_loss: 0.4643 - val_precision: 0.7862 - val_recall: 0.7557
# Epoch 13/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.7820 - loss: 0.4560 - precision: 0.7934 - recall: 0.7476 - val_accuracy: 0.7773 - val_loss: 0.4643 - val_precision: 0.7947 - val_recall: 0.7265
# Epoch 14/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - accuracy: 0.7828 - loss: 0.4505 - precision: 0.7940 - recall: 0.7488 - val_accuracy: 0.7812 - val_loss: 0.4663 - val_precision: 0.7904 - val_recall: 0.7443
# Epoch 15/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - accuracy: 0.7865 - loss: 0.4489 - precision: 0.7905 - recall: 0.7648 - val_accuracy: 0.7812 - val_loss: 0.4659 - val_precision: 0.7836 - val_recall: 0.7557
# Epoch 16/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - accuracy: 0.7838 - loss: 0.4482 - precision: 0.7902 - recall: 0.7576 - val_accuracy: 0.7797 - val_loss: 0.4661 - val_precision: 0.7800 - val_recall: 0.7573
# Epoch 17/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.7877 - loss: 0.4449 - precision: 0.7905 - recall: 0.7680 - val_accuracy: 0.7812 - val_loss: 0.4661 - val_precision: 0.7996 - val_recall: 0.7298
# Epoch 18/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - accuracy: 0.7928 - loss: 0.4422 - precision: 0.8044 - recall: 0.7596 - val_accuracy: 0.7758 - val_loss: 0.4672 - val_precision: 0.7782 - val_recall: 0.7492
# Epoch 19/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7855 - loss: 0.4444 - precision: 0.7893 - recall: 0.7640 - val_accuracy: 0.7773 - val_loss: 0.4679 - val_precision: 0.7780 - val_recall: 0.7540
# Epoch 20/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - accuracy: 0.7881 - loss: 0.4448 - precision: 0.7963 - recall: 0.7596 - val_accuracy: 0.7797 - val_loss: 0.4676 - val_precision: 0.7887 - val_recall: 0.7427
# Epoch 21/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 0.7930 - loss: 0.4380 - precision: 0.8019 - recall: 0.7640 - val_accuracy: 0.7758 - val_loss: 0.4676 - val_precision: 0.7727 - val_recall: 0.7589
#
# 3. Training Meta-Learning Model...
# ----------------------------------------
# Epoch 1/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6309 - loss: 0.6365 - precision: 0.6099 - recall: 0.6739 - val_accuracy: 0.7703 - val_loss: 0.5075 - val_precision: 0.7774 - val_recall: 0.7346
# Epoch 2/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7381 - loss: 0.5322 - precision: 0.7559 - recall: 0.6835 - val_accuracy: 0.7758 - val_loss: 0.4749 - val_precision: 0.7929 - val_recall: 0.7249
# Epoch 3/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7449 - loss: 0.5201 - precision: 0.7598 - recall: 0.6971 - val_accuracy: 0.7781 - val_loss: 0.4677 - val_precision: 0.7756 - val_recall: 0.7605
# Epoch 4/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7605 - loss: 0.4978 - precision: 0.7644 - recall: 0.7356 - val_accuracy: 0.7867 - val_loss: 0.4656 - val_precision: 0.7959 - val_recall: 0.7508
# Epoch 5/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.7609 - loss: 0.5004 - precision: 0.7751 - recall: 0.7179 - val_accuracy: 0.7867 - val_loss: 0.4639 - val_precision: 0.8021 - val_recall: 0.7411
# Epoch 6/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7695 - loss: 0.4881 - precision: 0.7807 - recall: 0.7332 - val_accuracy: 0.7789 - val_loss: 0.4646 - val_precision: 0.7769 - val_recall: 0.7605
# Epoch 7/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - accuracy: 0.7645 - loss: 0.4892 - precision: 0.7657 - recall: 0.7448 - val_accuracy: 0.7750 - val_loss: 0.4650 - val_precision: 0.7705 - val_recall: 0.7605
# Epoch 8/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.7691 - loss: 0.4818 - precision: 0.7756 - recall: 0.7408 - val_accuracy: 0.7750 - val_loss: 0.4639 - val_precision: 0.7778 - val_recall: 0.7476
# Epoch 9/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - accuracy: 0.7742 - loss: 0.4805 - precision: 0.7898 - recall: 0.7316 - val_accuracy: 0.7844 - val_loss: 0.4656 - val_precision: 0.8098 - val_recall: 0.7233
# Epoch 10/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7658 - loss: 0.4798 - precision: 0.7768 - recall: 0.7292 - val_accuracy: 0.7812 - val_loss: 0.4622 - val_precision: 0.8084 - val_recall: 0.7168
# Epoch 11/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7725 - loss: 0.4687 - precision: 0.7862 - recall: 0.7324 - val_accuracy: 0.7789 - val_loss: 0.4629 - val_precision: 0.7806 - val_recall: 0.7540
# Epoch 12/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7801 - loss: 0.4728 - precision: 0.7907 - recall: 0.7464 - val_accuracy: 0.7766 - val_loss: 0.4612 - val_precision: 0.7814 - val_recall: 0.7460
# Epoch 13/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7736 - loss: 0.4691 - precision: 0.7856 - recall: 0.7368 - val_accuracy: 0.7867 - val_loss: 0.4612 - val_precision: 0.8086 - val_recall: 0.7314
# Epoch 14/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - accuracy: 0.7777 - loss: 0.4644 - precision: 0.7922 - recall: 0.7376 - val_accuracy: 0.7789 - val_loss: 0.4618 - val_precision: 0.7825 - val_recall: 0.7508
# Epoch 15/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - accuracy: 0.7758 - loss: 0.4689 - precision: 0.7839 - recall: 0.7456 - val_accuracy: 0.7750 - val_loss: 0.4629 - val_precision: 0.7759 - val_recall: 0.7508
# Epoch 16/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - accuracy: 0.7711 - loss: 0.4698 - precision: 0.7836 - recall: 0.7328 - val_accuracy: 0.7797 - val_loss: 0.4621 - val_precision: 0.7781 - val_recall: 0.7605
# Epoch 17/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7770 - loss: 0.4673 - precision: 0.7854 - recall: 0.7464 - val_accuracy: 0.7781 - val_loss: 0.4625 - val_precision: 0.7909 - val_recall: 0.7346
# Epoch 18/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7752 - loss: 0.4673 - precision: 0.7890 - recall: 0.7356 - val_accuracy: 0.7828 - val_loss: 0.4638 - val_precision: 0.8004 - val_recall: 0.7330
# Epoch 19/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7840 - loss: 0.4675 - precision: 0.7920 - recall: 0.7552 - val_accuracy: 0.7773 - val_loss: 0.4630 - val_precision: 0.7734 - val_recall: 0.7621
# Epoch 20/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7771 - loss: 0.4657 - precision: 0.7887 - recall: 0.7416 - val_accuracy: 0.7781 - val_loss: 0.4627 - val_precision: 0.7840 - val_recall: 0.7460
# Epoch 21/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7750 - loss: 0.4635 - precision: 0.7838 - recall: 0.7436 - val_accuracy: 0.7758 - val_loss: 0.4646 - val_precision: 0.7745 - val_recall: 0.7557
# Epoch 22/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7828 - loss: 0.4566 - precision: 0.7973 - recall: 0.7436 - val_accuracy: 0.7766 - val_loss: 0.4628 - val_precision: 0.7795 - val_recall: 0.7492
# Epoch 23/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7814 - loss: 0.4616 - precision: 0.7897 - recall: 0.7520 - val_accuracy: 0.7781 - val_loss: 0.4650 - val_precision: 0.7747 - val_recall: 0.7621
#
# 4. RESULTS COMPARISON
# ============================================================
# Model                Dataset    Loss     Accuracy   Precision  Recall
# ----------------------------------------------------------------------
# Monolithic           Train      0.4355   0.7922     0.8036     0.7582
# Monolithic           Test       0.4879   0.7656     0.7669     0.7442
# Meta-Learning        Train      0.4464   0.7852     0.8145     0.7232
# Meta-Learning        Test       0.4878   0.7588     0.7737     0.7121
#
# 5. META-LEARNING IMPROVEMENTS:
#    Test Accuracy: -0.69 percentage points
#    Test Precision: +0.69 percentage points
#
# 6. DETAILED CLASSIFICATION REPORTS:
#
# Monolithic Model:
#               precision    recall  f1-score   support
#
#            0       0.76      0.79      0.78       822
#            1       0.77      0.74      0.76       778
#
#     accuracy                           0.77      1600
#    macro avg       0.77      0.77      0.77      1600
# weighted avg       0.77      0.77      0.77      1600
#
#
# Meta-Learning Model:
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77       822
#            1       0.77      0.71      0.74       778
#
#     accuracy                           0.76      1600
#    macro avg       0.76      0.76      0.76      1600
# weighted avg       0.76      0.76      0.76      1600
